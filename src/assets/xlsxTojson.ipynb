# %%
import pandas as pd

# %%
file = './busData.xlsx'

# %%
with open(file, 'rb') as f:
    df = pd.read_excel(f)
    print(df)
    df.to_json('./busData.json', orient='records', force_ascii=False, index=4)
# Out:
#          NODE_ID  ARS_ID           정류소명         X좌표        Y좌표
# 0      100000001    1001        종로2가사거리  126.987750  37.569765
# 1      100000002    1002    창경궁.서울대학교병원  126.996566  37.579183
# 2      100000003    1003      명륜3가.성대입구  126.998340  37.582671
# 3      100000004    1004       종로2가.삼일교  126.987613  37.568579
# 4      100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243
# ...          ...     ...            ...         ...        ...
# 12554  124000334   25995          우성아파트  127.139339  37.550386
# 12555  124000333   25996          우성아파트  127.140046  37.550643
# 12556  124000332   25997           조일약국  127.123596  37.533630
# 12557  124000331   25998           성내시장  127.125497  37.536155
# 12558  124000330   25999    천호우체국.로데오거리  127.127337  37.540343
#
# [12559 rows x 5 columns]
